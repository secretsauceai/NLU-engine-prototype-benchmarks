# %%
from nlu_engine import EntityExtractor, crf
from nlu_engine import Analytics
from nlu_engine import RenderJSON
from nlu_engine import DataUtils
from nlu_engine import MacroEntityRefinement
from nlu_engine import MacroDataRefinement

from nlu_engine import NLUEngine
import nltk
import pandas as pd
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# # Macro NLU Data Refinement

# %% [markdown]
# It's a bit like the TV show [Serverance](https://www.imdb.com/title/tt11280740/) .
#
# ![Helly R and Mark S](https://media.npr.org/assets/img/2022/02/15/atv_severance_photo_010103-5f8033cc2b219ba64fe265ce893eae4c90e83896-s1100-c50.jpg "Helly R and Mark G")
#
# *Helly R*: `My job is to scroll through the spreadsheet and look for the numbers that feel scary?`
#
# *Mark S*: `I told you, you’ll understand when you see it, so just be patient.`
#
# ![MDR](https://www.imore.com/sites/imore.com/files/styles/large/public/field/image/2022/03/refinement-software-severance-apple-tv.jpg "serverance micro data refinement")
#
# *Helly R*: `That was scary. The numbers were scary.`
#
# Hopefully the intents and entities that are wrong aren't scary, just a bit frustrating. Let's see if we can find the right ones.
#
# NOTE: We will use Logistic Regression with TFIDF features to train our intent models and CRFs for entity exraction. Why? Well, they are very fast and both methods aren't state-of-the-art. This is good, because it is easier to find problems we will need to refine in the dataset than if we were to use a proper NLU engine like Snips or something SOTA like BERT. It is very important to note that some of the the problems we will pick up on, might not be an actual issue, but might be due to the limitations of the models. Refining the real problems and ignoring the limitations of the models is a good way to improve the models. Then when the dataset is ready, we can use some more advanced NLU engine and get the best performance possible.
#
# * Macro NLU Data Refinement: Intent
# * Macro NLU Data Refinement: Entity

# %% [markdown]
# Load the dataset

# %%
try:
    nlu_data_df = pd.read_csv(
        'data/refined/nlu_data_refined_df.csv', sep=',', index_col=0)
    print('Successfully loaded nlu_data_refined_df.csv')
except:
    data = 'data/NLU-Data-Home-Domain-Annotated-All-Cleaned.csv'
    nlu_data_df = DataUtils.load_data(
    data
)
# Out:
# Successfully loaded nlu_data_refined_df.csv

# %% [markdown]
# Make sure `nlu_data_df['answer_normalised']` is taken from `nlu_data_df['answer_annotation']`

# %%
nlu_data_df = DataUtils.convert_annotated_utterances_to_normalised_utterances(
    nlu_data_df)

# %% [markdown]
# We should remove the unwanted entries for the next few steps.

# %%
removed_nlu_data_refined_df = nlu_data_df[nlu_data_df['remove'] != True]

# %% [markdown]
# # Entity extraction report

# %% [markdown]
# The entity extraction could be greatly improved by improving the features it uses. It would be great if someone would take a look at this. Perhaps the CRF features similar to what Snips uses would be better such as Brown clustering (probably).

# %% [markdown]
# It is important to have the NLTK tokenizer to be able to extract entities.

# %%
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
        nltk.download('punkt')

# %% [markdown]
# Due to this error featured in [this git issue](https://github.com/TeamHG-Memex/sklearn-crfsuite/issues/60) we have to use an older version of scikit learn (sklearn<0.24), otherwise the latest version would work. Hopefully this gets fixed one day..

# %%
entity_report_df = NLUEngine.evaluate_entity_classifier(
    data_df=removed_nlu_data_refined_df, cv=4)
# Out:
# Evaluating entity classifier
# Cross validating with CRF(algorithm='lbfgs', all_possible_transitions=True, c1=0.1, c2=0.1,
#     keep_tempfiles=None, max_iterations=100)
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Time it took to cross validate CRF(algorithm='lbfgs', all_possible_transitions=True, c1=0.1, c2=0.1,
#     keep_tempfiles=None, max_iterations=100): 330.08361625671387
# /home/bartmoss/code/NLU-engine-prototype-benchmarks/.venv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
entity_report_df
# Out:
#              entity-type  precision    recall  f1-score       support
# 0                      0   0.875369  0.953684  0.912850  64449.000000
# 1             alarm_type   0.000000  0.000000  0.000000     26.000000
# 2               app_name   0.878788  0.460317  0.604167     63.000000
# 3            artist_name   0.350877  0.285714  0.314961    560.000000
# 4       audiobook_author   0.000000  0.000000  0.000000     22.000000
# 5         audiobook_name   0.000000  0.000000  0.000000    235.000000
# 6          business_name   0.319149  0.153374  0.207182    489.000000
# 7          business_type   0.605714  0.305476  0.406130    347.000000
# 8          change_amount   0.000000  0.000000  0.000000    150.000000
# 9            coffee_type   1.000000  0.155556  0.269231     45.000000
# 10            color_type   0.736111  0.325153  0.451064    163.000000
# 11          cooking_type   0.000000  0.000000  0.000000     22.000000
# 12         currency_name   0.000000  0.000000  0.000000    864.000000
# 13                  date   0.870067  0.880224  0.875116   4283.000000
# 14       definition_word   0.000000  0.000000  0.000000    510.000000
# 15           device_type   0.763661  0.707595  0.734560    790.000000
# 16            drink_type   0.000000  0.000000  0.000000     20.000000
# 17         email_address   0.986928  0.909639  0.946708    166.000000
# 18          email_folder   0.980000  0.924528  0.951456     53.000000
# 19            event_name   0.435367  0.346787  0.386061   2428.000000
# 20             food_type   0.465854  0.280470  0.350137    681.000000
# 21             game_name   0.000000  0.000000  0.000000    239.000000
# 22             game_type   0.000000  0.000000  0.000000      3.000000
# 23     general_frequency   0.541667  0.103586  0.173913    251.000000
# 24           house_place   0.853242  0.609756  0.711238    410.000000
# 25            ingredient   0.000000  0.000000  0.000000     38.000000
# 26             joke_type   0.911765  0.413333  0.568807     75.000000
# 27             list_name   0.746736  0.542694  0.628571    527.000000
# 28             meal_type   0.761905  0.640000  0.695652    100.000000
# 29            media_type   0.299180  0.162584  0.210678    449.000000
# 30            movie_name   0.000000  0.000000  0.000000     32.000000
# 31            movie_type   0.000000  0.000000  0.000000     19.000000
# 32           music_album   0.000000  0.000000  0.000000      7.000000
# 33      music_descriptor   0.186047  0.061069  0.091954    131.000000
# 34           music_genre   0.738170  0.688235  0.712329    340.000000
# 35            news_topic   0.023211  0.047244  0.031128    508.000000
# 36            order_type   0.791667  0.521978  0.629139    182.000000
# 37                person   0.620155  0.510096  0.559767   1882.000000
# 38         personal_info   0.540000  0.369863  0.439024    146.000000
# 39            place_name   0.617567  0.624611  0.621069   2893.000000
# 40        player_setting   0.444444  0.186380  0.262626    279.000000
# 41         playlist_name   0.259259  0.104478  0.148936    201.000000
# 42    podcast_descriptor   0.000000  0.000000  0.000000    269.000000
# 43          podcast_name   0.021978  0.010929  0.014599    183.000000
# 44            radio_name   0.000000  0.000000  0.000000    914.000000
# 45              relation   0.850610  0.692308  0.763338    403.000000
# 46             song_name   0.108418  0.150977  0.126206    563.000000
# 47            sport_type   0.000000  0.000000  0.000000     13.000000
# 48                  time   0.806867  0.820065  0.813413   2751.000000
# 49             time_zone   0.666667  0.166667  0.266667    120.000000
# 50             timeofday   0.838554  0.899225  0.867830    387.000000
# 51      transport_agency   0.000000  0.000000  0.000000     72.000000
# 52  transport_descriptor   0.000000  0.000000  0.000000     33.000000
# 53        transport_name   0.000000  0.000000  0.000000     52.000000
# 54        transport_type   0.000000  0.000000  0.000000    508.000000
# 55    weather_descriptor   0.699083  0.524072  0.599057    727.000000
# 56              accuracy   0.812529  0.812529  0.812529      0.812529
# 57             macro avg   0.385626  0.277476  0.309742  92073.000000
# 58          weighted avg   0.776102  0.812529  0.790506  92073.000000

# %% [markdown]
# Optional: we can train a classifier and save the model to disk. For the default intent refined dataset, we already saved a model we can load one cell below.

# %%
crf_model = NLUEngine.train_entity_classifier(removed_nlu_data_refined_df)
model_path = 'models/analytics/entity_tagger.sav'
DataUtils.pickle_model(classifier=crf_model, model_path=model_path)

# %% [markdown]
# Let's load open up a model

# %%
model_path = 'models/analytics/entity_tagger.sav'
crf_model = DataUtils.import_pickled_model(model_path)

# %%
removed_nlu_data_refined_df['predicted_tagging'] = removed_nlu_data_refined_df['answer_normalised'].apply(
    lambda x: NLUEngine.create_entity_tagged_utterance(x, crf_model))
# Out:
# 4, failed for utterance: ['wake', 'me', 'up', 'at', 'five', 'am', 'this', 'week']
# 5, failed for utterance: ['wake', 'me', 'up', 'at', 'five', 'am', 'this', 'week']
# 6, failed for utterance: ['wake', 'me', 'up', 'at', 'five', 'am', 'this', 'week']
# 7, failed for utterance: ['wake', 'me', 'up', 'at', 'five', 'am', 'this', 'week']
# 4, failed for utterance: ['wake', 'me', 'up', 'at', 'nine', 'am', 'on', 'friday']
# 5, failed for utterance: ['wake', 'me', 'up', 'at', 'nine', 'am', 'on', 'friday']
# 7, failed for utterance: ['wake', 'me', 'up', 'at', 'nine', 'am', 'on', 'friday']
# 4, failed for utterance: ['set', 'an', 'alarm', 'for', 'two', 'hours', 'from', 'now']
# 5, failed for utterance: ['set', 'an', 'alarm', 'for', 'two', 'hours', 'from', 'now']
# 6, failed for utterance: ['set', 'an', 'alarm', 'for', 'two', 'hours', 'from', 'now']
# 7, failed for utterance: ['set', 'an', 'alarm', 'for', 'two', 'hours', 'from', 'now']
# 6, failed for utterance: ['make', 'the', 'lighting', 'a', 'bit', 'more', 'warm', 'here']
# 6, failed for utterance: ['turn', 'off', 'the', 'light', 'in', 'the', 'bathroom']
# 5, failed for utterance: ['dim', 'the', 'lights', 'in', 'the', 'hall']
# 6, failed for utterance: ['turn', 'the', 'lights', 'off', 'in', 'the', 'bedroom']
# 2, failed for utterance: ['set', 'lights', 'to', 'twenty', 'percent']
# 3, failed for utterance: ['set', 'lights', 'to', 'twenty', 'percent']
# 4, failed for utterance: ['set', 'lights', 'to', 'twenty', 'percent']
# 5, failed for utterance: ['dim', 'the', 'lights', 'in', 'the', 'kitchen']
# 2, failed for utterance: ['clean', 'the', 'flat']
# 2, failed for utterance: ['vacuum', 'the', 'house']
# 2, failed for utterance: ['hoover', 'the', 'hallway']
# 2, failed for utterance: ['hoover', 'the', 'carpets', 'around']
# 4, failed for utterance: ['i', 'want', 'to', 'listen', 'arijit', 'singh', 'song', 'once', 'again']
# 5, failed for utterance: ['i', 'want', 'to', 'listen', 'arijit', 'singh', 'song', 'once', 'again']
# 5, failed for utterance: ['is', 'the', 'brightness', 'of', 'my', 'screen', 'running', 'low']
# 6, failed for utterance: ['i', 'want', 'the', 'status', 'on', 'my', 'screen', 'brightness']
# 5, failed for utterance: ['what', "'s", 'the', 'time', 'in', 'australia']
# 5, failed for utterance: ['tell', 'me', 'the', 'time', 'in', 'moscow']
# 5, failed for utterance: ['tell', 'me', 'the', 'time', 'in', 'g.', 'm.', 't.', 'plus', 'five']
# 6, failed for utterance: ['tell', 'me', 'the', 'time', 'in', 'g.', 'm.', 't.', 'plus', 'five']
# 7, failed for utterance: ['tell', 'me', 'the', 'time', 'in', 'g.', 'm.', 't.', 'plus', 'five']
# 8, failed for utterance: ['tell', 'me', 'the', 'time', 'in', 'g.', 'm.', 't.', 'plus', 'five']
# 9, failed for utterance: ['tell', 'me', 'the', 'time', 'in', 'g.', 'm.', 't.', 'plus', 'five']
# 2, failed for utterance: ['most', 'rated', 'delivery', 'options', 'for', 'chinese', 'food']
# 5, failed for utterance: ['most', 'rated', 'delivery', 'options', 'for', 'chinese', 'food']
# 3, failed for utterance: ['i', 'want', 'some', 'curry', 'to', 'go', 'any', 'recommendations']
# 1, failed for utterance: ['find', 'thai', 'takeaways', 'around', 'grassmarket']
# 2, failed for utterance: ['find', 'thai', 'takeaways', 'around', 'grassmarket']
# 4, failed for utterance: ['find', 'thai', 'takeaways', 'around', 'grassmarket']
# 2, failed for utterance: ['cancel', 'my', 'seven', 'am', 'alarm']
# 3, failed for utterance: ['cancel', 'my', 'seven', 'am', 'alarm']
# 5, failed for utterance: ['remove', 'the', 'alarm', 'set', 'for', 'ten', 'pm']
# 6, failed for utterance: ['remove', 'the', 'alarm', 'set', 'for', 'ten', 'pm']
# 3, failed for utterance: ['whats', 'new', 'in', 'london']
# 3, failed for utterance: ['tell', 'me', 'latest', 'bbc', 'news']
# 4, failed for utterance: ['whats', 'happening', 'in', 'football', 'today']
# 2, failed for utterance: ['please', 'play', 'yesterday', 'from', 'beatles']
# 4, failed for utterance: ['please', 'play', 'yesterday', 'from', 'beatles']
# 7, failed for utterance: ['i', "'d", 'like', 'to', 'hear', 'queen', "'s", 'barcelona']
# 2, failed for utterance: ['play', 'me', 'barcelona', 'by', 'queen']
# 4, failed for utterance: ['play', 'me', 'barcelona', 'by', 'queen']
# 4, failed for utterance: ['please', 'raise', 'the', 'lights', 'to', 'max']
# 5, failed for utterance: ['please', 'raise', 'the', 'lights', 'to', 'max']
# 2, failed for utterance: ['hey', 'start', 'vacuum', 'cleaner', 'robot']
# 3, failed for utterance: ['hey', 'start', 'vacuum', 'cleaner', 'robot']
# 4, failed for utterance: ['hey', 'start', 'vacuum', 'cleaner', 'robot']
# 1, failed for utterance: ['enable', 'cleaner', 'robot']
# 2, failed for utterance: ['enable', 'cleaner', 'robot']
# 1, failed for utterance: ['turn', 'cleaner', 'robot', 'on']
# 2, failed for utterance: ['turn', 'cleaner', 'robot', 'on']
# 3, failed for utterance: ['what', 'is', 'it', 'today']
# 3, failed for utterance: ['please', 'order', 'some', 'sushi', 'for', 'dinner']
# 5, failed for utterance: ['please', 'order', 'some', 'sushi', 'for', 'dinner']
# 7, failed for utterance: ['hey', 'i', "'d", 'like', 'you', 'to', 'order', 'burger']
# 3, failed for utterance: ['could', 'you', 'order', 'sushi', 'for', 'tonight', 'dinner']
# 5, failed for utterance: ['could', 'you', 'order', 'sushi', 'for', 'tonight', 'dinner']
# 6, failed for utterance: ['could', 'you', 'order', 'sushi', 'for', 'tonight', 'dinner']
# 3, failed for utterance: ['whats', 'with', 'my', 'dinner', 'order']
# 3, failed for utterance: ['can', 'i', 'order', 'takeaway', 'dinner', 'from', 'byron', "'s"]
# 4, failed for utterance: ['can', 'i', 'order', 'takeaway', 'dinner', 'from', 'byron', "'s"]
# 4, failed for utterance: ['does', 'byron', "'s", 'supports', 'takeaways']
# 4, failed for utterance: ['set', 'an', 'alarm', 'for', 'twelve']
# 3, failed for utterance: ['set', 'an', 'alarm', 'forty', 'minutes', 'from', 'now']
# 4, failed for utterance: ['set', 'an', 'alarm', 'forty', 'minutes', 'from', 'now']
# 5, failed for utterance: ['set', 'an', 'alarm', 'forty', 'minutes', 'from', 'now']
# 6, failed for utterance: ['set', 'an', 'alarm', 'forty', 'minutes', 'from', 'now']
# 3, failed for utterance: ['set', 'alarm', 'for', 'eight', 'every', 'weekday']
# 4, failed for utterance: ['set', 'alarm', 'for', 'eight', 'every', 'weekday']
# 5, failed for utterance: ['set', 'alarm', 'for', 'eight', 'every', 'weekday']
# 2, failed for utterance: ['is', 'it', 'raining']
# 4, failed for utterance: ['is', 'it', 'going', 'to', 'rain']
# 3, failed for utterance: ['is', 'it', 'currently', 'snowing']
# 1, failed for utterance: ['whats', 'this', 'weeks', 'weather']
# 2, failed for utterance: ['whats', 'this', 'weeks', 'weather']
# 4, failed for utterance: ['tell', 'me', 'the', 'weather', 'this', 'week']
# 5, failed for utterance: ['tell', 'me', 'the', 'weather', 'this', 'week']
# 2, failed for utterance: ['tell', 'me', 'bbc', 'news']
# 3, failed for utterance: ['tell', 'me', 'bbc', 'news']
# 4, failed for utterance: ['whats', 'the', 'news', 'on', 'bbc', 'news']
# 1, failed for utterance: ['play', 'hurts', 'like', 'heaven']
# 2, failed for utterance: ['play', 'hurts', 'like', 'heaven']
# 3, failed for utterance: ['play', 'hurts', 'like', 'heaven']
# 2, failed for utterance: ['put', 'on', 'cannibal', 'queen']
# 3, failed for utterance: ['put', 'on', 'cannibal', 'queen']
# 1, failed for utterance: ['play', 'daft', 'punk']
# 2, failed for utterance: ['play', 'daft', 'punk']
# 3, failed for utterance: ['put', 'on', 'some', 'coldplay']
# 2, failed for utterance: ['play', 'some', 'david', 'bowie']
# 3, failed for utterance: ['play', 'some', 'david', 'bowie']
# 0, failed for utterance: ['shuffle', 'this', 'playlist']
# 3, failed for utterance: ['set', 'the', 'volume', 'to', 'low']
# 4, failed for utterance: ['set', 'the', 'volume', 'to', 'low']
# 3, failed for utterance: ['tell', 'me', 'a', 'good', 'joke']
# 3, failed for utterance: ['whats', 'the', 'day', 'today']
# 3, failed for utterance: ['tell', 'me', 'about', 'today']
# 2, failed for utterance: ['order', 'a', 'pizza']
# 3, failed for utterance: ['order', 'me', 'a', 'byron', 'from', 'deliveroo']
# 5, failed for utterance: ['order', 'me', 'a', 'byron', 'from', 'deliveroo']
# 2, failed for utterance: ['order', 'a', 'takeaway']
# 4, failed for utterance: ['how', 'long', 'until', 'my', 'takeaway']
# 2, failed for utterance: ['domino', "'s", 'delivery', 'status']
# 2, failed for utterance: ['play', 'my', 'jazz', 'playlist']
# 2, failed for utterance: ['start', 'my', 'jazz', 'playlist']
# 2, failed for utterance: ['play', 'my', 'favourite', 'playlist']
# 3, failed for utterance: ['play', 'my', 'favourite', 'playlist']
# 4, failed for utterance: ['can', 'you', 'play', 'some', 'jazz']
# 5, failed for utterance: ['i', 'like', 'to', 'listen', 'to', 'jazz']
# 1, failed for utterance: ['enable', 'shuffle']
# 2, failed for utterance: ['set', 'brightness', 'to', 'fifty', 'percent']
# 3, failed for utterance: ['set', 'brightness', 'to', 'fifty', 'percent']
# 4, failed for utterance: ['set', 'brightness', 'to', 'fifty', 'percent']
# 3, failed for utterance: ['i', 'fancy', 'some', 'coffee', 'now']
# 3, failed for utterance: ['can', 'they', 'provide', 'takeaway']
# 3, failed for utterance: ['can', 'they', 'do', 'delivery']
# 2, failed for utterance: ['do', 'they', 'deliver', 'home']
# 3, failed for utterance: ['set', 'alarm', 'at', 'ten', 'am']
# 4, failed for utterance: ['set', 'alarm', 'at', 'ten', 'am']
# 2, failed for utterance: ['set', 'alarm', 'tomorrow', 'at', 'six', 'am']
# 4, failed for utterance: ['set', 'alarm', 'tomorrow', 'at', 'six', 'am']
# 5, failed for utterance: ['set', 'alarm', 'tomorrow', 'at', 'six', 'am']
# 3, failed for utterance: ['set', 'wake', 'up', 'Thursday', 'seven', 'am']
# 4, failed for utterance: ['set', 'wake', 'up', 'Thursday', 'seven', 'am']
# 5, failed for utterance: ['set', 'wake', 'up', 'Thursday', 'seven', 'am']
# 3, failed for utterance: ['tell', 'me', 'latest', 'technology', 'news']
# 3, failed for utterance: ['tell', 'me', 'some', 'business', 'news']
# 2, failed for utterance: ['tell', 'me', 'international', 'news']
# 2, failed for utterance: ['is', 'it', 'raining', 'now']
# 2, failed for utterance: ['play', 'my', 'rock', 'playlist']
# 3, failed for utterance: ['play', 'my', 'rock', 'playlist']
# 3, failed for utterance: ['turn', 'on', 'my', 'michael', 'jackson', 'playlist']
# 4, failed for utterance: ['turn', 'on', 'my', 'michael', 'jackson', 'playlist']
# 1, failed for utterance: ['play', 'michael', 'jackson', 'from', 'my', 'playlist']
# 2, failed for utterance: ['play', 'michael', 'jackson', 'from', 'my', 'playlist']
# 6, failed for utterance: ['turn', 'on', 'my', 'playlist', 'and', 'play', 'third', 'song', 'in', 'the', 'queue']
# 1, failed for utterance: ['play', 'last', 'song', 'from', 'my', 'favourite', 'playlist']
# 2, failed for utterance: ['play', 'last', 'song', 'from', 'my', 'favourite', 'playlist']
# 5, failed for utterance: ['play', 'last', 'song', 'from', 'my', 'favourite', 'playlist']
# 6, failed for utterance: ['play', 'last', 'song', 'from', 'my', 'favourite', 'playlist']
# 3, failed for utterance: ['turn', 'on', 'the', 'plug']
# 3, failed for utterance: ['switch', 'on', 'the', 'plug']
# 3, failed for utterance: ['turn', 'on', 'my', 'plug']
# 1, failed for utterance: ['does', 'dominos', 'do', 'takeaway']
# 3, failed for utterance: ['does', 'dominos', 'do', 'takeaway']
# 3, failed for utterance: ['does', 'my', 'favourite', 'pizza', 'place', 'available', 'for', 'takeaway']
# 7, failed for utterance: ['does', 'my', 'favourite', 'pizza', 'place', 'available', 'for', 'takeaway']
# 3, failed for utterance: ['can', 'i', 'order', 'takeaway', 'from', 'spanish', 'place']
# 5, failed for utterance: ['can', 'i', 'order', 'takeaway', 'from', 'spanish', 'place']
# 6, failed for utterance: ['how', "'s", 'the', 'weather', 'like', 'in', 'beijing']
# 5, failed for utterance: ['tell', 'me', 'the', 'weather', 'in', 'shanghai']
# 5, failed for utterance: ['please', 'set', 'the', 'lights', 'to', 'green']
# 4, failed for utterance: ['please', 'make', 'the', 'lights', 'reading', 'friendly']
# 5, failed for utterance: ['please', 'make', 'the', 'lights', 'reading', 'friendly']
# 4, failed for utterance: ['please', 'make', 'the', 'lights', 'watching', 'friendly']
# 5, failed for utterance: ['please', 'make', 'the', 'lights', 'watching', 'friendly']
# 2, failed for utterance: ['make', 'the', 'room', 'brighter']
# 2, failed for utterance: ['what', "'s", 'today']
# 3, failed for utterance: ['what', 'day', 'is', 'today']
# 5, failed for utterance: ['how', 'is', 'the', 'weather', 'like', 'today']
# 2, failed for utterance: ['is', 'it', 'raining', 'outside']
# 4, failed for utterance: ['should', 'i', 'bring', 'an', 'umbrella', 'tomorrow']
# 5, failed for utterance: ['should', 'i', 'bring', 'an', 'umbrella', 'tomorrow']
# 4, failed for utterance: ['play', 'music', 'from', 'my', 'rock', 'list']
# 4, failed for utterance: ['change', 'the', 'lights', 'into', 'green']
# 2, failed for utterance: ['clean', 'the', 'floor', 'please']
# 3, failed for utterance: ['turn', 'on', 'the', 'rice', 'cooker', 'socket']
# 4, failed for utterance: ['turn', 'on', 'the', 'rice', 'cooker', 'socket']
# 5, failed for utterance: ['turn', 'on', 'the', 'rice', 'cooker', 'socket']
# 3, failed for utterance: ['turn', 'off', 'the', 'rice', 'cooker', 'socket']
# 4, failed for utterance: ['turn', 'off', 'the', 'rice', 'cooker', 'socket']
# 5, failed for utterance: ['turn', 'off', 'the', 'rice', 'cooker', 'socket']
# 5, failed for utterance: ['what', 'time', 'is', 'it', 'in', 'las', 'vegas']
# 6, failed for utterance: ['what', 'time', 'is', 'it', 'in', 'las', 'vegas']
# 5, failed for utterance: ['what', 'time', 'is', 'it', 'in', 'beijing']
# 8, failed for utterance: ['could', 'you', 'please', 'help', 'me', 'to', 'order', 'some', 'sushi', 'from', 'deliveroo']
# 10, failed for utterance: ['could', 'you', 'please', 'help', 'me', 'to', 'order', 'some', 'sushi', 'from', 'deliveroo']
# 4, failed for utterance: ['set', 'an', 'alarm', 'at', 'six', 'in', 'the', 'ofdaymorning']
# 4, failed for utterance: ['set', 'an', 'alarm', 'for', 'four', 'in', 'the', 'ofdayafternoon']
# 7, failed for utterance: ['do', 'i', 'have', 'an', 'alarm', 'set', 'for', 'morning', 'flight']
# 8, failed for utterance: ['do', 'i', 'have', 'an', 'alarm', 'set', 'for', 'morning', 'flight']
# 10, failed for utterance: ['did', 'i', 'set', 'an', 'alarm', 'to', 'wake', 'up', 'in', 'the', 'morning']
# 5, failed for utterance: ['what', "'s", 'the', 'weather', 'in', 'napels']
# 2, failed for utterance: ['is', 'it', 'raining', 'in', 'barcelona']
# 4, failed for utterance: ['is', 'it', 'raining', 'in', 'barcelona']
# 0, failed for utterance: ['sunny', 'in', 'oslo']
# 2, failed for utterance: ['sunny', 'in', 'oslo']
# 2, failed for utterance: ['will', 'it', 'rain', 'today']
# 3, failed for utterance: ['will', 'it', 'rain', 'today']
# 4, failed for utterance: ['what', "'s", 'happening', 'in', 'america']
# 6, failed for utterance: ['what', "'s", 'going', 'on', 'in', 'the', 'world']
# 4, failed for utterance: ['what', "'s", 'happening', 'in', 'cambridge']
# 5, failed for utterance: ['show', 'me', 'some', 'news', 'from', 'bbc']
# 1, failed for utterance: ['play', 'cnn', 'news']
# 3, failed for utterance: ['play', 'me', 'some', 'hihop']
# 7, failed for utterance: ['play', 'a', 'good', 'track', 'from', 'my', 'favourite', 'jazz', 'player']
# 5, failed for utterance: ['play', 'music', 'from', 'my', 'favorite', 'pianist']
# 3, failed for utterance: ['turn', 'the', 'lights', 'blue']
# 5, failed for utterance: ['let', "'s", 'have', 'the', 'lights', 'blue']
# 3, failed for utterance: ['make', 'the', 'lights', 'shine', 'blue']
# 4, failed for utterance: ['make', 'the', 'lights', 'shine', 'blue']
# 1, failed for utterance: ['good', 'night', 'lights', 'off']
# 2, failed for utterance: ['good', 'night', 'lights', 'off']
# 2, failed for utterance: ['is', 'it', 'five', "o'clock", 'already']
# 5, failed for utterance: ['what', "'s", 'the', 'time', 'in', 'new', 'york']
# 6, failed for utterance: ['what', "'s", 'the', 'time', 'in', 'new', 'york']
# 5, failed for utterance: ['what', "'s", 'the', 'time', 'in', 'tokyo', 'now']
# 4, failed for utterance: ['is', 'it', 'time', 'in', 'peru']
# 10, failed for utterance: ['what', 'the', 'singer', 'meant', 'by', 'the', 'title', 'of', 'the', 'song', 'bohemian', 'rhapsody']
# 11, failed for utterance: ['what', 'the', 'singer', 'meant', 'by', 'the', 'title', 'of', 'the', 'song', 'bohemian', 'rhapsody']
# 4, failed for utterance: ['who', 'covered', 'the', 'song', 'one', 'more', 'cup', 'of', 'coffee']
# 5, failed for utterance: ['who', 'covered', 'the', 'song', 'one', 'more', 'cup', 'of', 'coffee']
# 6, failed for utterance: ['who', 'covered', 'the', 'song', 'one', 'more', 'cup', 'of', 'coffee']
# 7, failed for utterance: ['who', 'covered', 'the', 'song', 'one', 'more', 'cup', 'of', 'coffee']
# 8, failed for utterance: ['who', 'covered', 'the', 'song', 'one', 'more', 'cup', 'of', 'coffee']
# 5, failed for utterance: ['what', 'is', 'the', 'weather', 'in', 'paris']
# 6, failed for utterance: ['what', 'is', 'the', 'weather', 'like', 'in', 'toronto']
# 6, failed for utterance: ['what', 'is', 'today', "'s", 'forecast', 'for', 'berlin']
# 7, failed for utterance: ['who', 'is', 'going', 'to', 'win', 'the', 'next', 'elections', 'in', 'the', 'france']
# 10, failed for utterance: ['who', 'is', 'going', 'to', 'win', 'the', 'next', 'elections', 'in', 'the', 'france']
# 5, failed for utterance: ['do', 'you', 'expect', 'sun', 'on', 'Sunday']
# 4, failed for utterance: ['is', 'it', 'going', 'to', 'rain', 'in', 'the', 'evening']
# 7, failed for utterance: ['is', 'it', 'going', 'to', 'rain', 'in', 'the', 'evening']
# 5, failed for utterance: ['is', 'it', 'going', 'to', 'be', 'windy', 'tomorrow']
# 6, failed for utterance: ['is', 'it', 'going', 'to', 'be', 'windy', 'tomorrow']
# 2, failed for utterance: ['brighten', 'the', 'lamp', 'next', 'to', 'the', 'sofa']
# 3, failed for utterance: ['brighten', 'the', 'lamp', 'next', 'to', 'the', 'sofa']
# 4, failed for utterance: ['brighten', 'the', 'lamp', 'next', 'to', 'the', 'sofa']
# 5, failed for utterance: ['brighten', 'the', 'lamp', 'next', 'to', 'the', 'sofa']
# 6, failed for utterance: ['brighten', 'the', 'lamp', 'next', 'to', 'the', 'sofa']
# 2, failed for utterance: ['it', 'is', 'five', 'forty', 'five', 'am', 'in', 'liverpool', 'what', 'is', 'now', 'new', 'york']
# 3, failed for utterance: ['it', 'is', 'five', 'forty', 'five', 'am', 'in', 'liverpool', 'what', 'is', 'now', 'new', 'york']
# 4, failed for utterance: ['it', 'is', 'five', 'forty', 'five', 'am', 'in', 'liverpool', 'what', 'is', 'now', 'new', 'york']
# 5, failed for utterance: ['it', 'is', 'five', 'forty', 'five', 'am', 'in', 'liverpool', 'what', 'is', 'now', 'new', 'york']
# 7, failed for utterance: ['it', 'is', 'five', 'forty', 'five', 'am', 'in', 'liverpool', 'what', 'is', 'now', 'new', 'york']
# 11, failed for utterance: ['it', 'is', 'five', 'forty', 'five', 'am', 'in', 'liverpool', 'what', 'is', 'now', 'new', 'york']
# 12, failed for utterance: ['it', 'is', 'five', 'forty', 'five', 'am', 'in', 'liverpool', 'what', 'is', 'now', 'new', 'york']
# 3, failed for utterance: ['given', 'it', 'is', 'four', 'thirty', 'five', 'pm', 'in', 'london', 'what', 'is', 'it', 'in', 'melbourne']
# 4, failed for utterance: ['given', 'it', 'is', 'four', 'thirty', 'five', 'pm', 'in', 'london', 'what', 'is', 'it', 'in', 'melbourne']
# 5, failed for utterance: ['given', 'it', 'is', 'four', 'thirty', 'five', 'pm', 'in', 'london', 'what', 'is', 'it', 'in', 'melbourne']
# 6, failed for utterance: ['given', 'it', 'is', 'four', 'thirty', 'five', 'pm', 'in', 'london', 'what', 'is', 'it', 'in', 'melbourne']
# 8, failed for utterance: ['given', 'it', 'is', 'four', 'thirty', 'five', 'pm', 'in', 'london', 'what', 'is', 'it', 'in', 'melbourne']
# 13, failed for utterance: ['given', 'it', 'is', 'four', 'thirty', 'five', 'pm', 'in', 'london', 'what', 'is', 'it', 'in', 'melbourne']
# 5, failed for utterance: ['what', 'time', 'is', 'it', 'in', 'moscow', 'now']
# 2, failed for utterance: ['start', 'a', 'vacuum', 'cleaner']
# 3, failed for utterance: ['start', 'a', 'vacuum', 'cleaner']
# 2, failed for utterance: ['vacuum', 'the', 'kitchen']
# 3, failed for utterance: ['turn', 'on', 'the', 'vacuum', 'cleaner']
# 4, failed for utterance: ['turn', 'on', 'the', 'vacuum', 'cleaner']
# 5, failed for utterance: ['what', 'is', 'happening', 'in', 'the', 'world']
# 2, failed for utterance: ['play', 'a', 'nirvana', 'playlist']
# 3, failed for utterance: ['play', 'a', 'nirvana', 'playlist']
# 0, failed for utterance: ['shuffle', 'songs', 'by', 'coldplay']
# 3, failed for utterance: ['shuffle', 'songs', 'by', 'coldplay']
# 1, failed for utterance: ['play', 'chopin']
# 5, failed for utterance: ['what', 'is', 'the', 'forecast', 'for', 'today']
# 0, failed for utterance: ['morning', 'what', "'s", 'up']
# 2, failed for utterance: ['order', 'a', 'pizza', 'from', 'pizza', 'express']
# 4, failed for utterance: ['order', 'a', 'pizza', 'from', 'pizza', 'express']
# 5, failed for utterance: ['order', 'a', 'pizza', 'from', 'pizza', 'express']
# 6, failed for utterance: ['i', 'would', 'like', 'to', 'have', 'a', 'sushi', 'can', 'you', 'order', 'me', 'a', 'lunch']
# 12, failed for utterance: ['i', 'would', 'like', 'to', 'have', 'a', 'sushi', 'can', 'you', 'order', 'me', 'a', 'lunch']
# 2, failed for utterance: ['order', 'a', 'takeaway', 'sandwich', 'and', 'soup', 'from', 'the', 'italian', "'s"]
# 3, failed for utterance: ['order', 'a', 'takeaway', 'sandwich', 'and', 'soup', 'from', 'the', 'italian', "'s"]
# 4, failed for utterance: ['order', 'a', 'takeaway', 'sandwich', 'and', 'soup', 'from', 'the', 'italian', "'s"]
# 5, failed for utterance: ['order', 'a', 'takeaway', 'sandwich', 'and', 'soup', 'from', 'the', 'italian', "'s"]
# 6, failed for utterance: ['how', 'many', 'days', 'are', 'left', 'in', 'this', 'year']
# 7, failed for utterance: ['how', 'many', 'days', 'are', 'left', 'in', 'this', 'year']
# 6, failed for utterance: ['what', 'day', 'is', 'new', 'year', "'s", 'eve', 'this', 'year']
# 7, failed for utterance: ['what', 'day', 'is', 'new', 'year', "'s", 'eve', 'this', 'year']
# 8, failed for utterance: ['what', 'day', 'is', 'new', 'year', "'s", 'eve', 'this', 'year']
# 5, failed for utterance: ['what', 'day', 'is', 'memorial', 'day', 'this', 'year']
# 6, failed for utterance: ['what', 'day', 'is', 'memorial', 'day', 'this', 'year']
# 2, failed for utterance: ['increase', 'brightness', 'by', 'twenty', 'percent']
# 3, failed for utterance: ['increase', 'brightness', 'by', 'twenty', 'percent']
# 4, failed for utterance: ['increase', 'brightness', 'by', 'twenty', 'percent']
# 2, failed for utterance: ['set', 'lights', 'to', 'full', 'power']
# 3, failed for utterance: ['set', 'lights', 'to', 'full', 'power']
# 4, failed for utterance: ['set', 'lights', 'to', 'full', 'power']
# 4, failed for utterance: ['please', 'be', 'quiet', 'for', 'another', 'hour']
# 5, failed for utterance: ['please', 'be', 'quiet', 'for', 'another', 'hour']
# 4, failed for utterance: ['is', 'it', 'going', 'to', 'rain', 'tomorrow']
# 5, failed for utterance: ['is', 'it', 'going', 'to', 'rain', 'tomorrow']
# 5, failed for utterance: ['tell', 'me', 'the', 'weather', 'in', 'barcelona', 'in', 'two', 'days', 'from', 'now']
# 7, failed for utterance: ['tell', 'me', 'the', 'weather', 'in', 'barcelona', 'in', 'two', 'days', 'from', 'now']
# 8, failed for utterance: ['tell', 'me', 'the', 'weather', 'in', 'barcelona', 'in', 'two', 'days', 'from', 'now']
# 9, failed for utterance: ['tell', 'me', 'the', 'weather', 'in', 'barcelona', 'in', 'two', 'days', 'from', 'now']
# 10, failed for utterance: ['tell', 'me', 'the', 'weather', 'in', 'barcelona', 'in', 'two', 'days', 'from', 'now']
# 4, failed for utterance: ['shall', 'i', 'get', 'an', 'umbrella', 'tomorrow']
# 5, failed for utterance: ['shall', 'i', 'get', 'an', 'umbrella', 'tomorrow']
# 2, failed for utterance: ['enable', 'my', 'plug']
# 3, failed for utterance: ['turn', 'on', 'the', 'smart', 'charger']
# 4, failed for utterance: ['turn', 'on', 'the', 'smart', 'charger']
# 6, failed for utterance: ['tell', 'me', 'some', 'fresh', 'info', 'from', 'daily', 'mail']
# 7, failed for utterance: ['tell', 'me', 'some', 'fresh', 'info', 'from', 'daily', 'mail']
# 5, failed for utterance: ['what', 'new', 'is', 'happening', 'in', 'business', 'according', 'to', 'the', 'economist']
# 9, failed for utterance: ['what', 'new', 'is', 'happening', 'in', 'business', 'according', 'to', 'the', 'economist']
# 5, failed for utterance: ['tell', 'me', 'the', 'news', 'in', 'technology', 'from', 'engadget']
# 7, failed for utterance: ['tell', 'me', 'the', 'news', 'in', 'technology', 'from', 'engadget']
# 6, failed for utterance: ['what', 'is', 'the', 'weather', 'condition', 'in', 'new', 'york']
# 7, failed for utterance: ['what', 'is', 'the', 'weather', 'condition', 'in', 'new', 'york']
# 7, failed for utterance: ['i', 'wish', 'to', 'know', 'the', 'weather', 'in', 'san', 'fransico']
# 8, failed for utterance: ['i', 'wish', 'to', 'know', 'the', 'weather', 'in', 'san', 'fransico']
# 2, failed for utterance: ['is', 'it', 'snowing', 'in', 'california']
# 4, failed for utterance: ['is', 'it', 'snowing', 'in', 'california']
# 2, failed for utterance: ['start', 'the', 'coffee', 'machine']
# 3, failed for utterance: ['start', 'the', 'coffee', 'machine']
# 5, failed for utterance: ['how', 'will', 'be', 'the', 'weather', 'tomorrow']
# 3, failed for utterance: ['will', 'it', 'be', 'rainy', 'tomorrow']
# 4, failed for utterance: ['will', 'it', 'be', 'rainy', 'tomorrow']
# 4, failed for utterance: ['what', 'will', 'be', 'the', 'temperature', 'out', 'there', 'tomorrow']
# 7, failed for utterance: ['what', 'will', 'be', 'the', 'temperature', 'out', 'there', 'tomorrow']
# 2, failed for utterance: ['what', 'is', 'tomorrows', 'weather', 'predictions']
# 2, failed for utterance: ['will', 'it', 'rain', 'tomorrow']
# 3, failed for utterance: ['will', 'it', 'rain', 'tomorrow']
# 3, failed for utterance: ['will', 'there', 'be', 'snow', 'tomorrow']
# 4, failed for utterance: ['will', 'there', 'be', 'snow', 'tomorrow']
# 4, failed for utterance: ['find', 'out', 'if', 'the', 'restaurant', 'does', 'takeaway', 'orders']
# 6, failed for utterance: ['find', 'out', 'if', 'the', 'restaurant', 'does', 'takeaway', 'orders']
# 3, failed for utterance: ['search', 'if', 'the', 'restaurant', 'does', 'take', 'out']
# 5, failed for utterance: ['search', 'if', 'the', 'restaurant', 'does', 'take', 'out']
# 6, failed for utterance: ['search', 'if', 'the', 'restaurant', 'does', 'take', 'out']
# 3, failed for utterance: ['is', 'there', 'a', 'takeout', 'menu', 'at', 'the', 'restaurant']
# 7, failed for utterance: ['is', 'there', 'a', 'takeout', 'menu', 'at', 'the', 'restaurant']
# 7, failed for utterance: ['what', 'day', 'of', 'the', 'week', 'is', 'the', 'twenty', 'second', 'march']
# 8, failed for utterance: ['what', 'day', 'of', 'the', 'week', 'is', 'the', 'twenty', 'second', 'march']
# 9, failed for utterance: ['what', 'day', 'of', 'the', 'week', 'is', 'the', 'twenty', 'second', 'march']
# 0, failed for utterance: ['twenty', 'ninth', 'march', 'comes', 'on', 'what', 'day']
# 1, failed for utterance: ['twenty', 'ninth', 'march', 'comes', 'on', 'what', 'day']
# 2, failed for utterance: ['twenty', 'ninth', 'march', 'comes', 'on', 'what', 'day']
# 6, failed for utterance: ['what', 'day', 'of', 'the', 'week', 'is', 'first', 'april']
# 7, failed for utterance: ['what', 'day', 'of', 'the', 'week', 'is', 'first', 'april']
# 7, failed for utterance: ['what', 'time', 'will', 'my', 'alarm', 'go', 'off', 'today']
# 5, failed for utterance: ['play', 'the', 'track', 'eight', 'from', 'google', 'play', 'music']
# 2, failed for utterance: ['is', 'it', 'Monday', 'today']
# 3, failed for utterance: ['is', 'it', 'Monday', 'today']
# 6, failed for utterance: ['what', "'s", 'the', 'weather', 'like', 'in', 'new', 'york', 'city']
# 7, failed for utterance: ['what', "'s", 'the', 'weather', 'like', 'in', 'new', 'york', 'city']
# 8, failed for utterance: ['what', "'s", 'the', 'weather', 'like', 'in', 'new', 'york', 'city']
# 3, failed for utterance: ['what', "'s", 'the', 'humidity', 'level']
# 4, failed for utterance: ['what', "'s", 'the', 'humidity', 'level']
# 2, failed for utterance: ['choose', 'that', 'music', 'player']
# 3, failed for utterance: ['choose', 'that', 'music', 'player']
# 2, failed for utterance: ['is', 'it', 'sunny', 'in', 'gonbad', 'now']
# 4, failed for utterance: ['is', 'it', 'sunny', 'in', 'gonbad', 'now']
# 2, failed for utterance: ['is', 'it', 'sunny', 'in', 'tehran']
# 4, failed for utterance: ['is', 'it', 'sunny', 'in', 'tehran']
# 2, failed for utterance: ['is', 'it', 'raining', 'here']
# 2, failed for utterance: ['please', 'play', 'games', 'by', 'disturbed']
# 4, failed for utterance: ['please', 'play', 'games', 'by', 'disturbed']
# 7, failed for utterance: ['please', 'open', 'my', 'music', 'application', 'and', 'play', 'games', 'by', 'disturbed']
# 9, failed for utterance: ['please', 'open', 'my', 'music', 'application', 'and', 'play', 'games', 'by', 'disturbed']
# 4, failed for utterance: ['please', 'play', 'the', 'song', 'games', 'by', 'disturbed']
# 6, failed for utterance: ['please', 'play', 'the', 'song', 'games', 'by', 'disturbed']
# 6, failed for utterance: ['turn', 'off', 'the', 'light', 'in', 'the', 'living', 'room']
# 7, failed for utterance: ['turn', 'off', 'the', 'light', 'in', 'the', 'living', 'room']
# 2, failed for utterance: ['turn', 'the', 'security', 'light', 'off']
# 3, failed for utterance: ['turn', 'the', 'security', 'light', 'off']
# 3, failed for utterance: ['turn', 'off', 'the', 'garage', 'light']
# 5, failed for utterance: ['check', 'for', 'hot', 'news', 'in', 'times', 'of', 'india']
# 6, failed for utterance: ['check', 'for', 'hot', 'news', 'in', 'times', 'of', 'india']
# 7, failed for utterance: ['check', 'for', 'hot', 'news', 'in', 'times', 'of', 'india']
# 1, failed for utterance: ['any', 'death', 'news', 'in', 'times', 'of', 'india']
# 4, failed for utterance: ['any', 'death', 'news', 'in', 'times', 'of', 'india']
# 5, failed for utterance: ['any', 'death', 'news', 'in', 'times', 'of', 'india']
# 6, failed for utterance: ['any', 'death', 'news', 'in', 'times', 'of', 'india']
# 4, failed for utterance: ['keep', 'me', 'posted', 'on', 'childcare', 'subject', 'in', 'the', 'news']
# 11, failed for utterance: ['let', 'me', 'know', 'as', 'soon', 'as', 'there', 'is', 'more', 'news', 'on', 'brexit']
# 3, failed for utterance: ['turn', 'off', 'the', 'smart', 'plug']
# 4, failed for utterance: ['turn', 'off', 'the', 'smart', 'plug']
# 2, failed for utterance: ['turn', 'the', 'smart', 'plug', 'on']
# 3, failed for utterance: ['turn', 'the', 'smart', 'plug', 'on']
# 2, failed for utterance: ['switch', 'the', 'smart', 'plug', 'socket', 'on']
# 3, failed for utterance: ['switch', 'the', 'smart', 'plug', 'socket', 'on']
# 4, failed for utterance: ['switch', 'the', 'smart', 'plug', 'socket', 'on']
# 2, failed for utterance: ['play', 'a', 'retro', 'song', 'in', 'my', 'playlist']
# 2, failed for utterance: ['what', 'is', 'twelve', 'pm', '_zoneeastern', 'in', '_zonepacific']
# 3, failed for utterance: ['what', 'is', 'twelve', 'pm', '_zoneeastern', 'in', '_zonepacific']
# 3, failed for utterance: ['if', 'it', 'is', 'noon', 'in', 'virginia', 'what', 'time', 'is', 'it', 'in', 'california']
# 5, failed for utterance: ['if', 'it', 'is', 'noon', 'in', 'virginia', 'what', 'time', 'is', 'it', 'in', 'california']
# 11, failed for utterance: ['if', 'it', 'is', 'noon', 'in', 'virginia', 'what', 'time', 'is', 'it', 'in', 'california']
# 6, failed for utterance: ['what', 'is', 'the', 'time', 'difference', 'between', 'eastern', 'time', 'and', 'pacific', 'time']
# 9, failed for utterance: ['what', 'is', 'the', 'time', 'difference', 'between', 'eastern', 'time', 'and', 'pacific', 'time']
# 1, failed for utterance: ['play', 'why', 'do', 'you', 'sing', 'by', 'kirk', 'franklin']
# 2, failed for utterance: ['play', 'why', 'do', 'you', 'sing', 'by', 'kirk', 'franklin']
# 3, failed for utterance: ['play', 'why', 'do', 'you', 'sing', 'by', 'kirk', 'franklin']
# 4, failed for utterance: ['play', 'why', 'do', 'you', 'sing', 'by', 'kirk', 'franklin']
# 6, failed for utterance: ['play', 'why', 'do', 'you', 'sing', 'by', 'kirk', 'franklin']
# 7, failed for utterance: ['play', 'why', 'do', 'you', 'sing', 'by', 'kirk', 'franklin']
# 4, failed for utterance: ['play', 'any', 'song', 'by', 'joe', 'prsaise']
# 5, failed for utterance: ['play', 'any', 'song', 'by', 'joe', 'prsaise']
# 1, failed for utterance: ['play', 'every', 'praise']
# 2, failed for utterance: ['play', 'every', 'praise']
# 2, failed for utterance: ['will', 'it', 'snow', 'tomorrow']
# 3, failed for utterance: ['will', 'it', 'snow', 'tomorrow']
# 3, failed for utterance: ['will', 'it', 'be', 'warm', 'tomorrow']
# 4, failed for utterance: ['will', 'it', 'be', 'warm', 'tomorrow']
# 2, failed for utterance: ['play', 'some', 'slow']
# 8, failed for utterance: ['can', 'you', 'change', 'the', 'light', 'colors', 'in', 'the', 'house']
# 2, failed for utterance: ['can', 'you', 'shuffle', 'the', 'light', 'colors', 'in', 'the', 'house']
# 8, failed for utterance: ['can', 'you', 'shuffle', 'the', 'light', 'colors', 'in', 'the', 'house']
# 7, failed for utterance: ['can', 'you', 'change', 'the', 'light', 'colors', 'into', 'dark', 'in', 'the', 'house']
# 10, failed for utterance: ['can', 'you', 'change', 'the', 'light', 'colors', 'into', 'dark', 'in', 'the', 'house']
# 2, failed for utterance: ['play', 'my', 'r', 'and', 'b', 'playlist']
# 3, failed for utterance: ['play', 'my', 'r', 'and', 'b', 'playlist']
# 4, failed for utterance: ['play', 'my', 'r', 'and', 'b', 'playlist']
# 5, failed for utterance: ['play', 'my', 'r', 'and', 'b', 'playlist']
# 6, failed for utterance: ['i', 'would', 'like', 'to', 'listen', 'to', 'pop', 'music', 'please']
# 3, failed for utterance: ['can', 'you', 'play', 'rock', 'music', 'for', 'the', 'next', 'hour']
# 7, failed for utterance: ['can', 'you', 'play', 'rock', 'music', 'for', 'the', 'next', 'hour']
# 8, failed for utterance: ['can', 'you', 'play', 'rock', 'music', 'for', 'the', 'next', 'hour']
# 3, failed for utterance: ['tell', 'me', 'a', 'funny', 'joke']
# 2, failed for utterance: ['change', 'my', 'room', 'lights', 'to', 'blue']
# 5, failed for utterance: ['change', 'my', 'room', 'lights', 'to', 'blue']
# 2, failed for utterance: ['change', 'my', 'room', 'lights', 'to', 'some', 'romantic', 'colour']
# 6, failed for utterance: ['change', 'my', 'room', 'lights', 'to', 'some', 'romantic', 'colour']
# 2, failed for utterance: ['change', 'my', 'room', 'lights', 'so', 'that', 'i', 'can', 'get', 'a', 'good', 'sleep']
# 10, failed for utterance: ['change', 'my', 'room', 'lights', 'so', 'that', 'i', 'can', 'get', 'a', 'good', 'sleep']
# 11, failed for utterance: ['change', 'my', 'room', 'lights', 'so', 'that', 'i', 'can', 'get', 'a', 'good', 'sleep']
# 6, failed for utterance: ['set', 'an', 'alarm', 'for', 'me', 'at', 'eight', 'am']
# 7, failed for utterance: ['set', 'an', 'alarm', 'for', 'me', 'at', 'eight', 'am']
# 4, failed for utterance: ['make', 'an', 'alarm', 'for', 'four', 'pm']
# 5, failed for utterance: ['make', 'an', 'alarm', 'for', 'four', 'pm']
# 3, failed for utterance: ['make', 'me', 'a', 'wake', 'up', 'alarm', 'for', 'eight', 'forty', 'five', 'am']
# 4, failed for utterance: ['make', 'me', 'a', 'wake', 'up', 'alarm', 'for', 'eight', 'forty', 'five', 'am']
# 7, failed for utterance: ['make', 'me', 'a', 'wake', 'up', 'alarm', 'for', 'eight', 'forty', 'five', 'am']
# 8, failed for utterance: ['make', 'me', 'a', 'wake', 'up', 'alarm', 'for', 'eight', 'forty', 'five', 'am']
# 9, failed for utterance: ['make', 'me', 'a', 'wake', 'up', 'alarm', 'for', 'eight', 'forty', 'five', 'am']
# 10, failed for utterance: ['make', 'me', 'a', 'wake', 'up', 'alarm', 'for', 'eight', 'forty', 'five', 'am']
# 3, failed for utterance: ['what', 'are', 'the', 'heartthrob', 'news']
# 3, failed for utterance: ['turn', 'on', 'the', 'plug', 'socket', 'one']
# 4, failed for utterance: ['turn', 'on', 'the', 'plug', 'socket', 'one']
# 5, failed for utterance: ['turn', 'on', 'the', 'plug', 'socket', 'one']
# 3, failed for utterance: ['power', 'down', 'the', 'plug', 'socket', 'one']
# 4, failed for utterance: ['power', 'down', 'the', 'plug', 'socket', 'one']
# 5, failed for utterance: ['power', 'down', 'the', 'plug', 'socket', 'one']
# 6, failed for utterance: ['turn', 'off', 'the', 'lights', 'in', 'the', 'bathroom']
# 3, failed for utterance: ['turn', 'off', 'the', 'bathroom', 'lights']
# 2, failed for utterance: ['lights', 'off', 'bathroom']
# 6, failed for utterance: ['what', "'s", 'the', 'weather', 'like', 'on', 'Friday']
# 1, failed for utterance: ['how', 'warm', 'is', 'it', 'outside', 'right', 'now']
# 1, failed for utterance: ['how', 'warm', 'is', 'it', 'right', 'now', 'outside']
# 2, failed for utterance: ['is', 'it', 'cold', 'outside', 'right', 'now']
# 4, failed for utterance: ['what', 'day', 'is', 'it', 'today']
# 7, failed for utterance: ['what', 'day', 'of', 'the', 'month', 'is', 'next', 'tuesday']
# 1, failed for utterance: ['play', 'bad', 'religion', 'folder']
# 2, failed for utterance: ['play', 'bad', 'religion', 'folder']
# 4, failed for utterance: ['play', 'all', 'albums', 'by', 'bad', 'religion']
# 5, failed for utterance: ['play', 'all', 'albums', 'by', 'bad', 'religion']
# 4, failed for utterance: ['is', 'it', 'going', 'to', 'rain', 'today']
# 5, failed for utterance: ['is', 'it', 'going', 'to', 'rain', 'today']
# 4, failed for utterance: ['should', 'i', 'wear', 'a', 'jacket', 'today']
# 5, failed for utterance: ['should', 'i', 'wear', 'a', 'jacket', 'today']
# 0, failed for utterance: ['disable', 'shuffle']
# 1, failed for utterance: ['disable', 'shuffle']
# 0, failed for utterance: ['repeat', 'album']
# 1, failed for utterance: ['play', 'metallica']
# 6, failed for utterance: ['what', 'playlists', 'do', 'you', 'have', 'for', 'pop', 'music']
# 1, failed for utterance: ['play', 'old', 'fashioned', 'christmas', 'music']
# 2, failed for utterance: ['play', 'old', 'fashioned', 'christmas', 'music']
# 3, failed for utterance: ['play', 'old', 'fashioned', 'christmas', 'music']
# 1, failed for utterance: ['run', 'coffee', 'maker']
# 2, failed for utterance: ['run', 'coffee', 'maker']
# 1, failed for utterance: ['make', 'coffee']
# 1, failed for utterance: ['access', 'coffee', 'maker', 'begin', 'process']
# 2, failed for utterance: ['access', 'coffee', 'maker', 'begin', 'process']
# 5, failed for utterance: ['change', 'the', 'lights', 'in', 'the', 'kitchen', 'to', 'blue']
# 7, failed for utterance: ['change', 'the', 'lights', 'in', 'the', 'kitchen', 'to', 'blue']
# 5, failed for utterance: ['fix', 'the', 'lights', 'in', 'the', 'living', 'room', 'to', 'red']
# 6, failed for utterance: ['fix', 'the', 'lights', 'in', 'the', 'living', 'room', 'to', 'red']
# 8, failed for utterance: ['fix', 'the', 'lights', 'in', 'the', 'living', 'room', 'to', 'red']
# 2, failed for utterance: ['change', 'the', 'bedroom', 'lights', 'to', 'green']
# 5, failed for utterance: ['change', 'the', 'bedroom', 'lights', 'to', 'green']
# 5, failed for utterance: ['i', 'want', 'to', 'listen', 'to', 'rock', 'music']
# 4, failed for utterance: ['i', 'want', 'to', 'listen', 'classical', 'music']
# 4, failed for utterance: ['i', 'want', 'to', 'listen', 'jazz']
# 2, failed for utterance: ['brighten', 'my', 'bedroom', 'light']
# 2, failed for utterance: ['turn', 'off', 'lamp']
# 3, failed for utterance: ['play', 'songs', 'by', 'sia']
# 2, failed for utterance: ['play', 'the', 'weekend']
# 3, failed for utterance: ['open', 'songs', 'by', 'prince']
# 3, failed for utterance: ['find', 'news', 'about', 'brexit']
# 3, failed for utterance: ['open', 'news', 'about', 'bp', 'oil']
# 4, failed for utterance: ['open', 'news', 'about', 'bp', 'oil']
# 4, failed for utterance: ['find', 'me', 'news', 'about', 'trumps', 'speech']
# 5, failed for utterance: ['find', 'me', 'news', 'about', 'trumps', 'speech']
# 2, failed for utterance: ['tell', 'me', 'the', 'hour']
# 3, failed for utterance: ['tell', 'me', 'the', 'hour']
# 6, failed for utterance: ['what', 'time', 'is', 'it', 'in', 'the', 'other', 'time', 'zones']
# 7, failed for utterance: ['what', 'time', 'is', 'it', 'in', 'the', 'other', 'time', 'zones']
# 8, failed for utterance: ['what', 'time', 'is', 'it', 'in', 'the', 'other', 'time', 'zones']
# 4, failed for utterance: ['what', 'time', 'zone', 'is', 'arizona']
# 6, failed for utterance: ['what', 'time', 'is', 'it', 'in', 'the', 'east']
# 5, failed for utterance: ['what', 'time', 'is', 'it', 'in', 'new', 'york', 'city']
# 6, failed for utterance: ['what', 'time', 'is', 'it', 'in', 'new', 'york', 'city']
# 7, failed for utterance: ['what', 'time', 'is', 'it', 'in', 'new', 'york', 'city']
# 5, failed for utterance: ['what', 'is', 'the', 'time', 'in', 'india', 'right', 'now']
# 7, failed for utterance: ['what', 'time', 'is', 'it', 'right', 'now', 'in', 'australia']
# 3, failed for utterance: ['what', 'is', 'the', 'temperature', 'outside']
# 2, failed for utterance: ['is', 'it', 'hot', 'outside']
# 2, failed for utterance: ['is', 'is', 'cold', 'outside']
# 2, failed for utterance: ['whats', 'a', 'silly', 'joke', 'you', 'know']
# 2, failed for utterance: ['whats', 'a', 'good', 'joke']
# 2, failed for utterance: ['select', 'the', 'music', 'player']
# 3, failed for utterance: ['select', 'the', 'music', 'player']
# 5, failed for utterance: ['change', 'the', 'light', 'color', 'to', 'blue']
# 5, failed for utterance: ['change', 'the', 'light', 'color', 'to', 'red']
# 5, failed for utterance: ['what', 'time', 'is', 'it', 'in', 'des', 'moines']
# 6, failed for utterance: ['what', 'time', 'is', 'it', 'in', 'des', 'moines']
# 4, failed for utterance: ['whats', 'the', 'time', 'in', 'denver']
# 4, failed for utterance: ['hows', 'the', 'time', 'in', 'key', 'largo']
# 5, failed for utterance: ['hows', 'the', 'time', 'in', 'key', 'largo']
# 1, failed for utterance: ['play', 'tonic']
# 3, failed for utterance: ['play', 'songs', 'by', 'adele']
# 3, failed for utterance: ['open', 'songs', 'from', 'major', 'lazer']
# 4, failed for utterance: ['open', 'songs', 'from', 'major', 'lazer']
# 7, failed for utterance: ['mute', 'yourself', 'when', 'i', 'am', 'in', 'a', 'meeting']
# 3, failed for utterance: ['mute', 'for', 'the', 'next', 'hour', 'please']
# 4, failed for utterance: ['mute', 'for', 'the', 'next', 'hour', 'please']
# 1, failed for utterance: ['play', 'neverland', 'by', 'metallica']
# 3, failed for utterance: ['play', 'neverland', 'by', 'metallica']
# 2, failed for utterance: ['tell', 'me', 'random', 'joke']
# 3, failed for utterance: ['what', "'s", 'your', 'favorite', 'joke']
# 4, failed for utterance: ['what', 'are', 'the', 'latest', 'world', 'news']
# 4, failed for utterance: ['please', 'tell', 'me', 'some', 'international', 'news']
# 4, failed for utterance: ['what', 'are', 'the', 'latest', 'international', 'updates', 'in', 'the', 'world']
# 8, failed for utterance: ['what', 'are', 'the', 'latest', 'international', 'updates', 'in', 'the', 'world']
# 4, failed for utterance: ['set', 'an', 'alarm', 'for', 'nine', 'am']
# 5, failed for utterance: ['set', 'an', 'alarm', 'for', 'nine', 'am']
# 6, failed for utterance: ['set', 'a', 'wake', 'up', 'call', 'for', 'ten', 'am']
# 7, failed for utterance: ['set', 'a', 'wake', 'up', 'call', 'for', 'ten', 'am']
# 6, failed for utterance: ['i', 'need', 'a', 'reminder', 'alarm', 'at', 'one']
# 4, failed for utterance: ['make', 'an', 'alarm', 'for', 'three', 'pm']
# 5, failed for utterance: ['make', 'an', 'alarm', 'for', 'three', 'pm']
# 5, failed for utterance: ['turn', 'on', 'an', 'alarm', 'for', 'nine', 'am']
# 6, failed for utterance: ['turn', 'on', 'an', 'alarm', 'for', 'nine', 'am']
# 4, failed for utterance: ['set', 'an', 'alarm', 'for', 'one', 'pm']
# 5, failed for utterance: ['set', 'an', 'alarm', 'for', 'one', 'pm']
# 5, failed for utterance: ['play', 'the', 'song', 'sung', 'by', 'katy', 'perry']
# 6, failed for utterance: ['play', 'the', 'song', 'sung', 'by', 'katy', 'perry']
# 3, failed for utterance: ['play', 'the', 'song', 'immediately']
# 3, failed for utterance: ['what', "'s", 'the', 'funniest', 'joke']
# 3, failed for utterance: ['tell', 'me', 'a', 'dirty', 'joke']
# 1, failed for utterance: ['choose', 'music', 'player']
# 2, failed for utterance: ['choose', 'music', 'player']
# 7, failed for utterance: ['please', 'increase', 'the', 'volume', 'of', 'the', 'music', 'hips', 'do', "n't", 'lie']
# 10, failed for utterance: ['please', 'increase', 'the', 'volume', 'of', 'the', 'music', 'hips', 'do', "n't", 'lie']
# 6, failed for utterance: ['turn', 'the', 'lights', 'off', 'in', 'the', 'living', 'room']
# 7, failed for utterance: ['turn', 'the', 'lights', 'off', 'in', 'the', 'living', 'room']
# 7, failed for utterance: ['please', 'set', 'the', 'lights', 'off', 'in', 'the', 'living', 'room']
# 8, failed for utterance: ['please', 'set', 'the', 'lights', 'off', 'in', 'the', 'living', 'room']
# 2, failed for utterance: ['light', 'off', 'living', 'room']
# 3, failed for utterance: ['light', 'off', 'living', 'room']
# 1, failed for utterance: ['play', 'mf', 'doom', 'anything']
# 2, failed for utterance: ['play', 'mf', 'doom', 'anything']
# 4, failed for utterance: ['can', 'i', 'get', 'some', 'background', 'music']
# 7, failed for utterance: ['do', 'i', 'have', 'any', 'alarms', 'set', 'for', 'tomorrow']
# 6, failed for utterance: ['what', "'s", 'the', 'alarm', 'situation', 'for', 'tomorrow']
# 2, failed for utterance: ['turn', 'off', 'eight', 'am', 'alarm']
# 3, failed for utterance: ['turn', 'off', 'eight', 'am', 'alarm']
# 2, failed for utterance: ['cancel', 'my', 'eight', 'am', 'alarm']
# 3, failed for utterance: ['cancel', 'my', 'eight', 'am', 'alarm']
# 4, failed for utterance: ['get', 'rid', 'of', 'my', 'eight', 'am', 'alarm']
# 5, failed for utterance: ['get', 'rid', 'of', 'my', 'eight', 'am', 'alarm']
# 3, failed for utterance: ['what', "'s", 'the', 'temperature']
# 1, failed for utterance: ['how', 'warm', 'is', 'it']
# 1, failed for utterance: ['how', 'cold', 'is', 'it']
# 2, failed for utterance: ['is', 'it', 'second', 'Saturday', 'on', 'twelfth']
# 3, failed for utterance: ['is', 'it', 'second', 'Saturday', 'on', 'twelfth']
# 5, failed for utterance: ['is', 'it', 'second', 'Saturday', 'on', 'twelfth']
# 2, failed for utterance: ['is', 'there', 'christmas', 'on', 'twenty', 'second']
# 4, failed for utterance: ['is', 'there', 'christmas', 'on', 'twenty', 'second']
# 5, failed for utterance: ['is', 'there', 'christmas', 'on', 'twenty', 'second']
# 0, failed for utterance: ['repeat', 'same', 'song', 'for', 'ten', 'times']
# 1, failed for utterance: ['play', 'one', 'through', 'ten', 'on', 'list']
# 2, failed for utterance: ['play', 'one', 'through', 'ten', 'on', 'list']
# 3, failed for utterance: ['play', 'one', 'through', 'ten', 'on', 'list']
# 5, failed for utterance: ['turn', 'off', 'one', 'light', 'on', 'porch']
# 2, failed for utterance: ['turn', 'the', 'lamp', 'off']
# 3, failed for utterance: ['will', 'it', 'be', 'raining', 'tomorrow']
# 4, failed for utterance: ['will', 'it', 'be', 'raining', 'tomorrow']
# 5, failed for utterance: ['will', 'there', 'be', 'sunset', 'at', 'five', 'thirty', 'pm', 'tomorrow']
# 6, failed for utterance: ['will', 'there', 'be', 'sunset', 'at', 'five', 'thirty', 'pm', 'tomorrow']
# 7, failed for utterance: ['will', 'there', 'be', 'sunset', 'at', 'five', 'thirty', 'pm', 'tomorrow']
# 8, failed for utterance: ['will', 'there', 'be', 'sunset', 'at', 'five', 'thirty', 'pm', 'tomorrow']
# 5, failed for utterance: ['is', 'there', 'any', 'chances', 'of', 'rain', 'this', 'week']
# 6, failed for utterance: ['is', 'there', 'any', 'chances', 'of', 'rain', 'this', 'week']
# 7, failed for utterance: ['is', 'there', 'any', 'chances', 'of', 'rain', 'this', 'week']
# 5, failed for utterance: ['what', 'is', 'new', 'news', 'for', 'today']
# 6, failed for utterance: ['what', 'is', 'the', 'time', 'in', 'the', 'pacific', 'time', 'zone']
# 6, failed for utterance: ['what', 'is', 'the', 'time', 'in', 'the', 'eastern', 'time', 'zone']
# 5, failed for utterance: ['what', 'is', 'the', 'time', 'in', 'alaska']
# 1, failed for utterance: ['how', 'warm', 'is', 'it', 'now']
# 4, failed for utterance: ['can', 'i', 'hear', 'the', 'fifty', 'hits', 'that', 'you', 'can', 'hear', 'on', 'radios', 'now']
# 5, failed for utterance: ['can', 'i', 'hear', 'the', 'fifty', 'hits', 'that', 'you', 'can', 'hear', 'on', 'radios', 'now']
# 3, failed for utterance: ['please', 'turn', 'on', 'classic', 'music', 'for', 'the', 'dinner', 'now']
# 5, failed for utterance: ['please', 'i', 'want', 'to', 'hear', 'we', 'will', 'rock', 'you', 'from', 'queen']
# 6, failed for utterance: ['please', 'i', 'want', 'to', 'hear', 'we', 'will', 'rock', 'you', 'from', 'queen']
# 7, failed for utterance: ['please', 'i', 'want', 'to', 'hear', 'we', 'will', 'rock', 'you', 'from', 'queen']
# ...
# 3, failed for utterance: ['check', 'email', 'from', 'john']
# 7, failed for utterance: ['thanks', 'but', 'i', 'think', 'you', 'did', "n't", 'understand', 'command', 'correctly', '.']
# 8, failed for utterance: ['thanks', 'but', 'i', 'think', 'you', 'did', "n't", 'understand', 'command', 'correctly', '.']
# 2, failed for utterance: ['oh', 'my', 'god', 'why', 'did', 'you', 'do', 'that', '.']
# 10, failed for utterance: ['i', 'am', 'sorry', 'but', 'i', 'think', 'you', 'did', 'not', 'get', 'command', 'right', '.']
# 6, failed for utterance: ['sorry', 'but', 'you', 'did', 'not', 'get', 'command', 'right', '.']
# 11, failed for utterance: ['i', 'am', 'sorry', 'but', 'i', 'think', 'you', 'did', 'not', 'interpret', 'the', 'command', 'right', '.']
# 9, failed for utterance: ['i', 'am', 'sorry', 'but', 'you', 'do', 'not', 'get', 'the', 'command', 'right', '.']
# 4, failed for utterance: ['olly', 'i', 'said', 'call', 'jack', 'not', 'jake', '.']
# 5, failed for utterance: ['wrong', 'i', 'will', 'repeat', 'the', 'command', 'now', '.']
# 3, failed for utterance: ['any', 'one', 'is', 'fine', 'with', 'me', '.']
# 3, failed for utterance: ['any', 'one', 'is', 'fine', 'for', 'me', ',', 'olly', '.']
# 4, failed for utterance: ['can', 'you', 'try', 'the', 'last', 'one', 'you', 'just', 'said', 'one', 'more', 'time', 'please', '.']
# 5, failed for utterance: ['can', 'you', 'try', 'the', 'last', 'one', 'you', 'just', 'said', 'one', 'more', 'time', 'please', '.']
# 6, failed for utterance: ['can', 'you', 'try', 'the', 'last', 'one', 'you', 'just', 'said', 'one', 'more', 'time', 'please', '.']
# 2, failed for utterance: ['would', 'you', 'repeat', 'please', '.']
# 2, failed for utterance: ['can', 'you', 'replay', 'please', '.']
# 4, failed for utterance: ['would', 'you', 'try', 'the', 'last', 'one', 'spoken', 'one', 'more', 'time', 'again', 'please', '.']
# 5, failed for utterance: ['would', 'you', 'try', 'the', 'last', 'one', 'spoken', 'one', 'more', 'time', 'again', 'please', '.']
# 6, failed for utterance: ['would', 'you', 'try', 'the', 'last', 'one', 'spoken', 'one', 'more', 'time', 'again', 'please', '.']
# 3, failed for utterance: ['please', 'speak', 'the', 'last', 'one', 'said', 'one', 'more', 'time', '.']
# 4, failed for utterance: ['please', 'speak', 'the', 'last', 'one', 'said', 'one', 'more', 'time', '.']
# 5, failed for utterance: ['please', 'speak', 'the', 'last', 'one', 'said', 'one', 'more', 'time', '.']
# 0, failed for utterance: ['repeat', 'your', 'last', 'sentence', 'you', 'just', 'said', '.']
# 1, failed for utterance: ['please', 'repeat', 'the', 'last', 'sentence', 'said', '.']
# 6, failed for utterance: ['let', "'s", 'try', 'the', 'last', 'word', 'spoken', 'one', 'more', 'again', 'please', '.']
# 3, failed for utterance: ['please', 'would', 'you', 'repeat', 'that', '.']
# 0, failed for utterance: ['repeat', 'that', '.']
# 6, failed for utterance: ['i', "'d", 'like', 'to', 'hear', 'the', 'last', 'one', 'spoke', 'again', '.']
# 7, failed for utterance: ['i', "'d", 'like', 'to', 'hear', 'the', 'last', 'one', 'spoke', 'again', '.']
# 8, failed for utterance: ['i', "'d", 'like', 'to', 'hear', 'the', 'last', 'one', 'spoke', 'again', '.']
# 5, failed for utterance: ['could', 'you', 'tell', 'me', 'the', 'last', 'one', 'you', 'just', 'said', 'again', 'please', '.']
# 6, failed for utterance: ['could', 'you', 'tell', 'me', 'the', 'last', 'one', 'you', 'just', 'said', 'again', 'please', '.']
# 7, failed for utterance: ['could', 'you', 'tell', 'me', 'the', 'last', 'one', 'you', 'just', 'said', 'again', 'please', '.']
# 1, failed for utterance: ['please', 'repeat', 'that', '.']
# 2, failed for utterance: ['will', 'you', 'replay', 'please', '.']
# 2, failed for utterance: ['could', 'you', 'start', 'over', 'please', '.']
# 3, failed for utterance: ['could', 'you', 'start', 'over', 'please', '.']
# 4, failed for utterance: ['can', 'you', 'retry', 'the', 'last', 'one', 'said', 'please', '.']
# 5, failed for utterance: ['can', 'you', 'retry', 'the', 'last', 'one', 'said', 'please', '.']
# 6, failed for utterance: ['can', 'you', 'retry', 'the', 'last', 'one', 'said', 'please', '.']
# 0, failed for utterance: ['replay', 'please', '.']
# 6, failed for utterance: ['i', 'would', 'like', 'to', 'hear', 'the', 'last', 'you', 'just', 'said', 'again', '.']
# 7, failed for utterance: ['i', 'would', 'like', 'to', 'hear', 'the', 'last', 'you', 'just', 'said', 'again', '.']
# 2, failed for utterance: ['would', 'you', 'replay', 'please', '.']
# 2, failed for utterance: ['can', 'you', 'start', 'over', 'please', '.']
# 3, failed for utterance: ['can', 'you', 'start', 'over', 'please', '.']
# 2, failed for utterance: ['can', 'you', 'repeat', 'please', '.']
# 3, failed for utterance: ['please', 'try', 'the', 'last', 'one', 'you', 'said', 'once', 'more', '.']
# 4, failed for utterance: ['please', 'try', 'the', 'last', 'one', 'you', 'said', 'once', 'more', '.']
# 5, failed for utterance: ['please', 'try', 'the', 'last', 'one', 'you', 'said', 'once', 'more', '.']
# 4, failed for utterance: ['would', 'you', 'say', 'the', 'last', 'one', 'said', 'one', 'more', 'again', 'please', '.']
# 5, failed for utterance: ['would', 'you', 'say', 'the', 'last', 'one', 'said', 'one', 'more', 'again', 'please', '.']
# 6, failed for utterance: ['would', 'you', 'say', 'the', 'last', 'one', 'said', 'one', 'more', 'again', 'please', '.']
# 6, failed for utterance: ['i', 'would', 'like', 'to', 'hear', 'the', 'last', 'one', 'spoken', 'again', '.']
# 7, failed for utterance: ['i', 'would', 'like', 'to', 'hear', 'the', 'last', 'one', 'spoken', 'again', '.']
# 8, failed for utterance: ['i', 'would', 'like', 'to', 'hear', 'the', 'last', 'one', 'spoken', 'again', '.']
# 3, failed for utterance: ['please', 'would', 'you', 'repeat', 'what', 'you', "'ve", 'said', '.']
# 2, failed for utterance: ['could', 'you', 'replay', 'please', '.']
# 6, failed for utterance: ['i', 'would', 'like', 'to', 'hear', 'the', 'last', 'one', 'you', 'said', 'again', '.']
# 7, failed for utterance: ['i', 'would', 'like', 'to', 'hear', 'the', 'last', 'one', 'you', 'said', 'again', '.']
# 8, failed for utterance: ['i', 'would', 'like', 'to', 'hear', 'the', 'last', 'one', 'you', 'said', 'again', '.']
# 0, failed for utterance: ['let', 'us', 'try', 'the', 'last', 'one', 'you', 'just', 'said', 'again', 'please', '.']
# 1, failed for utterance: ['let', 'us', 'try', 'the', 'last', 'one', 'you', 'just', 'said', 'again', 'please', '.']
# 2, failed for utterance: ['let', 'us', 'try', 'the', 'last', 'one', 'you', 'just', 'said', 'again', 'please', '.']
# 3, failed for utterance: ['let', 'us', 'try', 'the', 'last', 'one', 'you', 'just', 'said', 'again', 'please', '.']
# 4, failed for utterance: ['let', 'us', 'try', 'the', 'last', 'one', 'you', 'just', 'said', 'again', 'please', '.']
# 5, failed for utterance: ['let', 'us', 'try', 'the', 'last', 'one', 'you', 'just', 'said', 'again', 'please', '.']
# 6, failed for utterance: ['let', 'us', 'try', 'the', 'last', 'one', 'you', 'just', 'said', 'again', 'please', '.']
# 4, failed for utterance: ['could', 'you', 'say', 'the', 'last', 'one', 'spoken', 'one', 'more', 'again', '.']
# 5, failed for utterance: ['could', 'you', 'say', 'the', 'last', 'one', 'spoken', 'one', 'more', 'again', '.']
# 6, failed for utterance: ['could', 'you', 'say', 'the', 'last', 'one', 'spoken', 'one', 'more', 'again', '.']
# 3, failed for utterance: ['tell', 'me', 'the', 'last', 'one', 'spoken', 'once', 'more', 'please', '.']
# 4, failed for utterance: ['tell', 'me', 'the', 'last', 'one', 'spoken', 'once', 'more', 'please', '.']
# 5, failed for utterance: ['tell', 'me', 'the', 'last', 'one', 'spoken', 'once', 'more', 'please', '.']
# 6, failed for utterance: ['tell', 'me', 'the', 'last', 'one', 'spoken', 'once', 'more', 'please', '.']
# 7, failed for utterance: ['tell', 'me', 'the', 'last', 'one', 'spoken', 'once', 'more', 'please', '.']
# 5, failed for utterance: ['i', 'want', 'to', 'hear', 'the', 'last', 'one', 'spoken', 'again', '.']
# 6, failed for utterance: ['i', 'want', 'to', 'hear', 'the', 'last', 'one', 'spoken', 'again', '.']
# 7, failed for utterance: ['i', 'want', 'to', 'hear', 'the', 'last', 'one', 'spoken', 'again', '.']
# 2, failed for utterance: ['could', 'you', 'repeat', 'that', 'please', '.']
# 4, failed for utterance: ['please', 'tell', 'me', 'the', 'last', 'one', 'spoken', 'one', 'more', 'time', '.']
# 5, failed for utterance: ['please', 'tell', 'me', 'the', 'last', 'one', 'spoken', 'one', 'more', 'time', '.']
# 6, failed for utterance: ['please', 'tell', 'me', 'the', 'last', 'one', 'spoken', 'one', 'more', 'time', '.']
# 2, failed for utterance: ['will', 'you', 'start', 'over', 'please', '.']
# 3, failed for utterance: ['will', 'you', 'start', 'over', 'please', '.']
# 2, failed for utterance: ['would', 'you', 'repeat', 'what', 'said', 'please', '.']
# 7, failed for utterance: ['please', 'can', 'you', 'tell', 'me', 'that', 'word', 'said', 'once', 'again', '.']
# 0, failed for utterance: ['repeat', 'please', '.']
# 6, failed for utterance: ['i', 'need', 'to', 'hear', 'the', 'word', 'spoken', 'again', '.']
# 2, failed for utterance: ['could', 'you', 'repeat', 'that', '.']
# 2, failed for utterance: ['speak', 'the', 'last', 'one', 'you', 'said', 'one', 'more', 'again', 'please', '.']
# 3, failed for utterance: ['speak', 'the', 'last', 'one', 'you', 'said', 'one', 'more', 'again', 'please', '.']
# 4, failed for utterance: ['speak', 'the', 'last', 'one', 'you', 'said', 'one', 'more', 'again', 'please', '.']
# 5, failed for utterance: ['speak', 'the', 'last', 'one', 'you', 'said', 'one', 'more', 'again', 'please', '.']
# 0, failed for utterance: ['stop', 'and', 'start', 'over', '.']
# 1, failed for utterance: ['stop', 'and', 'start', 'over', '.']
# 2, failed for utterance: ['stop', 'and', 'start', 'over', '.']
# 4, failed for utterance: ['would', 'you', 'try', 'the', 'last', 'one', 'you', 'just', 'said', 'once', 'again', '.']
# 5, failed for utterance: ['would', 'you', 'try', 'the', 'last', 'one', 'you', 'just', 'said', 'once', 'again', '.']
# 6, failed for utterance: ['would', 'you', 'try', 'the', 'last', 'one', 'you', 'just', 'said', 'once', 'again', '.']
# 5, failed for utterance: ['please', 'can', 'you', 'speak', 'the', 'last', 'one', 'said', 'once', 'more', '.']
# 6, failed for utterance: ['please', 'can', 'you', 'speak', 'the', 'last', 'one', 'said', 'once', 'more', '.']
# 7, failed for utterance: ['please', 'can', 'you', 'speak', 'the', 'last', 'one', 'said', 'once', 'more', '.']
# 2, failed for utterance: ['would', 'you', 'start', 'over', 'please', '.']
# 3, failed for utterance: ['would', 'you', 'start', 'over', 'please', '.']
# 5, failed for utterance: ['i', 'want', 'to', 'hear', 'the', 'last', 'you', 'just', 'said', 'again', '.']
# 6, failed for utterance: ['i', 'want', 'to', 'hear', 'the', 'last', 'you', 'just', 'said', 'again', '.']
# 3, failed for utterance: ['tell', 'me', 'the', 'last', 'once', 'again', 'please', '.']
# 4, failed for utterance: ['tell', 'me', 'the', 'last', 'once', 'again', 'please', '.']
# 4, failed for utterance: ['can', 'you', 'try', 'the', 'last', 'one', 'spoken', 'once', 'again', '.']
# 5, failed for utterance: ['can', 'you', 'try', 'the', 'last', 'one', 'spoken', 'once', 'again', '.']
# 6, failed for utterance: ['can', 'you', 'try', 'the', 'last', 'one', 'spoken', 'once', 'again', '.']
# 7, failed for utterance: ['can', 'you', 'try', 'the', 'last', 'one', 'spoken', 'once', 'again', '.']
# 2, failed for utterance: ['would', 'you', 'repeat', 'the', 'last', 'please', '.']
# 5, failed for utterance: ['i', 'want', 'to', 'hear', 'the', 'last', 'one', 'you', 'said', 'again', '.']
# 6, failed for utterance: ['i', 'want', 'to', 'hear', 'the', 'last', 'one', 'you', 'said', 'again', '.']
# 7, failed for utterance: ['i', 'want', 'to', 'hear', 'the', 'last', 'one', 'you', 'said', 'again', '.']
# 4, failed for utterance: ['you', "'ve", 'done', 'the', 'command', 'right', '.']
# 4, failed for utterance: ['yes', 'you', 'did', 'the', 'command', 'right', '.']
# 4, failed for utterance: ['you', 'have', 'done', 'the', 'command', 'right', '.']
# 0, failed for utterance: ['yeah', 'got', 'that', 'perfectly', '.']
# 3, failed for utterance: ['you', 'got', 'the', 'command', 'right', '.']
# 4, failed for utterance: ['you', "'ve", 'got', 'the', 'command', 'right', '.']
# 2, failed for utterance: ['get', 'the', 'command', 'right', '.']
# 4, failed for utterance: ['yeah', 'you', 'get', 'the', 'command', 'right', '.']
# 0, failed for utterance: ['yeah', 'got', 'the', 'answer', 'exactly', '.']
# 2, failed for utterance: ['would', 'you', 'stop', 'please', '.']
# 2, failed for utterance: ['will', 'you', 'stop', 'please', '.']
# 2, failed for utterance: ['could', 'you', 'stop', 'please', '.']
# 2, failed for utterance: ['can', 'you', 'stop', 'please', '.']
# 3, failed for utterance: ['olly', 'will', 'you', 'stop', 'please', '.']
# 4, failed for utterance: ['i', 'want', 'you', 'to', 'check', 'the', 'question', 'please', '.']
# 5, failed for utterance: ['i', 'want', 'you', 'to', 'check', 'the', 'question', 'please', '.']
# 6, failed for utterance: ['i', 'want', 'you', 'to', 'check', 'the', 'question', 'please', '.']
# 5, failed for utterance: ['i', 'would', 'like', 'you', 'to', 'check', 'instruction', 'please', '.']
# 6, failed for utterance: ['i', 'would', 'like', 'you', 'to', 'check', 'instruction', 'please', '.']
# 5, failed for utterance: ['i', 'would', 'like', 'you', 'to', 'check', 'the', 'question', 'please', '.']
# 6, failed for utterance: ['i', 'would', 'like', 'you', 'to', 'check', 'the', 'question', 'please', '.']
# 7, failed for utterance: ['i', 'would', 'like', 'you', 'to', 'check', 'the', 'question', 'please', '.']
# 4, failed for utterance: ['i', 'want', 'you', 'to', 'check', 'instruction', 'please', '.']
# 5, failed for utterance: ['i', 'want', 'you', 'to', 'check', 'instruction', 'please', '.']
# 4, failed for utterance: ['did', 'you', 'get', 'my', 'last', 'command', 'correctly', '?']
# 5, failed for utterance: ['did', 'you', 'get', 'my', 'last', 'command', 'correctly', '?']
# 4, failed for utterance: ['i', 'want', 'you', 'to', 'check', 'command', 'please', '.']
# 5, failed for utterance: ['i', 'want', 'you', 'to', 'check', 'command', 'please', '.']
# 5, failed for utterance: ['i', "'d", 'like', 'you', 'to', 'check', 'detail', 'please', '.']
# 6, failed for utterance: ['i', "'d", 'like', 'you', 'to', 'check', 'detail', 'please', '.']
# 5, failed for utterance: ['s1', ',', 'elaborate', 'me', 'on', 'this', 'once', 'again', '.']
# 6, failed for utterance: ['s1', ',', 'elaborate', 'me', 'on', 'this', 'once', 'again', '.']
# 5, failed for utterance: ['again', 'clarify', 'me', 'on', 'your', 'answers', 'please', '.']
# 7, failed for utterance: ['could', 'you', 'again', 'elaborate', 'me', 'on', 'your', 'answers', 'please', '.']
# 7, failed for utterance: ['could', 'you', 'explain', 'me', 'further', 'on', 'your', 'answers', 'please', '.']
# 6, failed for utterance: ['will', 'you', 'please', 'explain', 'me', 'about', 'this', 'once', 'again', '.']
# 7, failed for utterance: ['will', 'you', 'please', 'explain', 'me', 'about', 'this', 'once', 'again', '.']
# 5, failed for utterance: ['could', 'you', 'clarify', 'me', 'on', 'this', 'once', 'again', 'please', '.']
# 6, failed for utterance: ['could', 'you', 'clarify', 'me', 'on', 'this', 'once', 'again', 'please', '.']
# 4, failed for utterance: ['clarify', 'more', 'on', 'your', 'answers', 'please', '.']
# 5, failed for utterance: ['s1', ',', 'again', 'clarify', 'your', 'answers', 'please', '.']
# 6, failed for utterance: ['once', 'again', 'clarify', 'me', 'about', 'your', 'answers', 'please', '.']
# 5, failed for utterance: ['s1', ',', 'further', 'elaborate', 'your', 'answers', 'please', '.']
# 5, failed for utterance: ['again', 'explain', 'me', 'about', 'your', 'answers', 'please', '.']
# /home/bartmoss/code/NLU-engine-prototype-benchmarks/.venv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
incorrect_tagged_df = removed_nlu_data_refined_df[removed_nlu_data_refined_df['answer_annotation']
                            != removed_nlu_data_refined_df['predicted_tagging']]


incorrect_tagged_domain_count_df = incorrect_tagged_df.groupby('scenario').size(
).reset_index(name='count').sort_values(by='count', ascending=False)

# %%
incorrect_tagged_domain_count_df
# Out:
#           scenario  count
# 2         calendar    681
# 12              qa    523
# 11            play    424
# 6          general    321
# 5            email    315
# 7              iot    198
# 4         datetime    192
# 16         weather    153
# 10            news    140
# 8            lists    132
# 15       transport    122
# 13  recommendation     95
# 14        takeaway     89
# 0            alarm     65
# 1            audio     49
# 3          cooking     41
# 9            music     21

# %%
incorrect_tagged_df['entity_types'] = incorrect_tagged_df['answer_annotation'].apply(
    EntityExtractor.extract_entities)

#TODO: get the entities and find the counts for each entity type!
# Out:
# /home/bartmoss/code/NLU-engine-prototype-benchmarks/.venv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#TODO: load domain input and get analytics of that domain
#TODO: refine by that domain for each intent (?)

# %%
#TODO: extract entity types and join them together?
incorrect_tagged_df
# Out:
#        userid  answerid notes  \
# 21        1.0      52.0   NaN
# 26      181.0    5063.0   NaN
# 29      224.0    6242.0   NaN
# 32     1003.0   27047.0   NaN
# 50        2.0     584.0   NaN
# ...       ...       ...   ...
# 24745     NaN     499.0   NaN
# 24786     NaN     540.0   NaN
# 24824     NaN     578.0   NaN
# 24831     NaN     585.0   NaN
# 24876     NaN     630.0   NaN
#
#                                                 question suggested_entities  \
# 21     How would you ask your PDA to activate your ro...                NaN
# 26     Write what you would tell your PDA in the foll...                NaN
# 29      How would you tell your PDA to confirm a setting                NaN
# 32      How would you tell your PDA to confirm a setting                NaN
# 50     How would you ask your PDA for news from a par...        news_source
# ...                                                  ...                ...
# 24745                                                NaN                NaN
# 24786                                                NaN                NaN
# 24824                                                NaN                NaN
# 24831                                                NaN                NaN
# 24876                                                NaN                NaN
#
#                                                   answer  \
# 21     cleaning is good, dust is so bad do now your m...
# 26                  I WANT TO PLAY THAT MUSIC ONE AGAIN.
# 29           Is the brightness of my screen running low?
# 32             I want the status on my screen brightness
# 50                    Whats happening in football today?
# ...                                                  ...
# 24745               clarify more on your answers please.
# 24786             s1, again clarify your answers please.
# 24824   once again clarify me about your answers please.
# 24831         s1, further elaborate your answers please.
# 24876        again explain me about your answers please.
#
#                                        answer_normalised scenario      intent  \
# 21     cleaning is good dust is so bad do now your ma...      iot    cleaning
# 26                   i want to play that music one again     play       music
# 29            is the brightness of my screen running low  general      quirky
# 32             i want the status on my screen brightness  general      quirky
# 50                     whats happening in football today     news  news_query
# ...                                                  ...      ...         ...
# 24745               clarify more on your answers please.  general     explain
# 24786             s1, again clarify your answers please.  general     explain
# 24824   once again clarify me about your answers please.  general     explain
# 24831         s1, further elaborate your answers please.  general     explain
# 24876        again explain me about your answers please.  general     explain
#
#       predicted_label intent_refined  entity_refined remove status  \
# 21           cleaning            NaN             NaN    NaN    NaN
# 26              music            NaN             NaN    NaN    NaN
# 29             quirky            NaN             NaN    NaN    NaN
# 32             quirky            NaN             NaN    NaN    NaN
# 50         news_query            NaN             NaN    NaN    NaN
# ...               ...            ...             ...    ...    ...
# 24745         explain            NaN             NaN    NaN    NaN
# 24786         explain            NaN             NaN    NaN    NaN
# 24824         explain            NaN             NaN    NaN    NaN
# 24831         explain            NaN             NaN    NaN    NaN
# 24876         explain            NaN             NaN    NaN    NaN
#
#                                        answer_annotation  \
# 21     cleaning is good dust is so bad do now your ma...
# 26     i want to play that [media_type : music] one a...
# 29            is the brightness of my screen running low
# 32             i want the status on my screen brightness
# 50     whats happening in [news_topic : football] [da...
# ...                                                  ...
# 24745               clarify more on your answers please.
# 24786             s1, again clarify your answers please.
# 24824   once again clarify me about your answers please.
# 24831         s1, further elaborate your answers please.
# 24876        again explain me about your answers please.
#
#                                        predicted_tagging  \
# 21     cleaning is good dust is so bad do now your ma...
# 26                   i want to play that music one again
# 29     is the brightness of my [device_type : screen]...
# 32     i want the status on my [device_type : screen]...
# 50            whats happening in football [date : today]
# ...                                                  ...
# 24745  clarify more on your [relation : answers] please.
# 24786  s1, again clarify your [relation : answers] pl...
# 24824  once again clarify me about your [relation : a...
# 24831  s1, further elaborate your [relation : answers...
# 24876  again explain me about your [relation : answer...
#
#                                             entity_types
# 21        [{'type': 'house_place', 'words': ['carpet']}]
# 26          [{'type': 'media_type', 'words': ['music']}]
# 29                                                    []
# 32                                                    []
# 50     [{'type': 'news_topic', 'words': ['football']}...
# ...                                                  ...
# 24745                                                 []
# 24786                                                 []
# 24824                                                 []
# 24831                                                 []
# 24876                                                 []
#
# [3561 rows x 17 columns]
